# %%
import core.backup as bck
import core.constants as cst
import core.correction as cor
import core.reduction as red
import core.pending as pd
import core.utils as ut
from core.plugin import Plugin

# DEBUG-ONLY
from importlib import reload
mods = [bck, cst, cor, red, pd, ut]
for mod in mods:
    reload(mod)
        
#---------------------------------------------------#

import argparse
from datetime import datetime
import inspect
import os
import pkgutil
import sys
import time
import warnings

class PluginCollector(object):
    """ Upon creation, this class will read the plugins
        package for modules that contain a class definition
        that is inheriting from the Plugin class.
    """

    def __init__(self):
        """ Constructor that initiates the reading of all available
            plugins when an instance of the PluginCollector object
            is created.
        """
        self.plugin_package = "plugins"
        self.plugins = []
        self.find_plugins()

    def find_plugins(self):
        """ Find and store all Plugin-inherited plugins stored in
            the '/plugins' folder. Append them to the list in the 
            attribute plugins.
        """
        imported_package = __import__(self.plugin_package, fromlist=[""])

        for _, pluginname, ispkg in pkgutil.iter_modules(imported_package.__path__, imported_package.__name__ + '.'):
            if not ispkg:
                plugin_module = __import__(pluginname, fromlist=[""])
                clsmembers = inspect.getmembers(plugin_module, inspect.isclass)
                for (_, c) in clsmembers:
                    # Only add classes that are a sub class of Plugin, but NOT Plugin itself
                    if issubclass(c, Plugin) & (c is not Plugin):
                        self.plugins.append(c())

def load_args():
    """ Function that specifies the expected arguments
        given on the command line by the user.
    """
    
    # Sets the description that will be shown with --help
    parser = argparse.ArgumentParser(description="Program that updates the Blaauw Observatory \
                                                  database by automatically reducing the fits files")
    
    # Add required argument for path to observation folder
    target = parser.add_mutually_exclusive_group()
    target.add_argument("-f", "--folder", type=str, help="The absolute path to the observation directory")
    target.add_argument("-d", "--date", type=str, help="The observation date in yy-mm-dd")
    target.add_argument("-u", "--update", action='store_const', const=datetime.today().strftime("%y-%m-%d"),
                        dest="date", help="Select todays directory if it exists")
    
    # Add arguments for the intended action
    parser.add_argument("-b", "--backup", action="store_true", help="Move a copy of the raw data to local folder")
    parser.add_argument("-c", "--correction", action="store_true", help="Save raw correction frames locally")
    parser.add_argument("-r", "--reduce", action="store_true", help="Reduce all the present light frames")
    #parser.add_argument("-p", "--preview", action="store_true", help="Create a .png preview per light file")
    parser.add_argument("-p", "--pending", action="store_true", help="Rerun pending reductions")
    parser.add_argument("-m", "--modules", action="store_true", help="Run external modules stored in /plugins")
    
    # Add argument for verbosity
    parser.add_argument("-v", "--verbose", action="store_true", help="Increase the amount of output")
    
    # Retrieve the passed arguments and check their validity
    args = parser.parse_args()
    targets = ut.check_args(parser, args)
    
    return args, targets

def run_plugins(obs, working_dir, args):
    # Collect all plugins
    loaded_plugins = PluginCollector()
    # Execute each plugin
    for plugin in loaded_plugins.plugins:
        ut.Print(f"Running external plugin: {plugin.title}", args)
        plugin.on_run(obs, working_dir, args)
        ut.Print(f"{plugin.title} executed", args)
    
def run_plugins_single(obs, working_dir, args, file, called_from):
    # Collect all plugins
    loaded_plugins = PluginCollector()
    # Execute each plugin for a specific file only
    for plugin in loaded_plugins.plugins:
        # Only rerun plugin if specified by plugin
        # TODO: not really elegant to compare strings...
        if (called_from == "pending" and plugin.rerun_on_pending) or \
           (called_from == "astromety" and plugin.rerun_on_astrometry):
            ut.Print(f"(Re)running external plugin: {plugin.title}", args)
            plugin.on_run_single(obs, working_dir, args, file)
            ut.Print(f"{plugin.title} (re-)executed", args)

def run_backup(obs, working_dir, args):
    ut.Print("Creating backup...", args, True)
    bck.create_backup(obs, working_dir, args)
    ut.Print("Backup created!", args, True)
    
def run_correction(obs, working_dir, args):
    ut.Print("Saving correction frames...", args, True)
    cor.save_correction(obs, working_dir, args)
    ut.Print("Correction frames saved!", args, True)

def run_reduce(obs, working_dir, args):
    ut.Print("Reducing images...", args, True)
    red.reduce_imgs(obs, working_dir, args)
    ut.Print("Images reduced!", args, True)
    
def run_pending(obs, working_dir, args):
    ut.Print("Rerunning pending reductions...", args, True)
    pd.rerun_pending(obs, working_dir, args)
    ut.Print("Pending list updated!", args, True)

def main():
    # Retrieve the arguments, and the specified targets
    args, targets = load_args()
    
    # Loop over every target that was found and perform the actions 
    # that were specified in the command line arguments
    for target in targets:
        ut.Print(f"Currently handling: {target}", args, True)
        
        # Construct a working dir where all *new/altered* data goes
        working_dir_name = os.path.relpath(target, cst.tele_path)
        working_dir = os.path.join(cst.base_path, working_dir_name)
        
        # Extra check if the working dir already exists, else create it
        if os.path.isdir(working_dir):
            # TODO: this means this data probably has been handled already...
            # BUT: not sure what exact operations have been carried out
            # Maybe we can put some sort of log in each handled dir, containing
            # a list of all actions that were already performed? Seems better 
            # than just 'checking' manually what has or hasn't been done yet.
            #print("Folder existed")
            pass
        else:
            os.makedirs(working_dir)
        
        # Create observation object for this target
        obs = ut.get_observation(target, args)
    
        # Perform core functions
        if args.backup: run_backup(obs, working_dir, args)
        if args.correction: run_correction(obs, working_dir, args)
        if args.reduce: run_reduce(obs, working_dir, args)
        if args.pending: run_pending(obs, working_dir, args)
            
        # Execute plugins
        if args.modules: run_plugins(obs, working_dir, args)
    
if __name__ == "__main__":
    # placeholder
    # data_dir = "/net/vega/data/users/observatory/images/200417/STL-6303E/i/"
    date = "20-04-20"
    #date = "20-05-05"
    #22 april
    
    sys.argv = ["controller.py", "-d", date, "-bcrv"]
#    sys.argv = ["controller.py", "-d", date, "-bv"]
#     sys.argv = ["controller.py", "-u", "-rv"]
    main()
# Out:
# 16:28:50.195245 Found data in 1 subdir(s)
# 16:28:50.195353 Currently handling: /net/vega/data/users/observatory/images/200420/STL-6303E/i
# 16:28:50.199479 Creating Observation object...
# 16:28:51.316125 Found 123 fits files
# 16:28:51.316197 Found 27 bias frames
# 16:28:51.316234 Found 4 dark frames
# 16:28:51.316282 Found 15 flat fields
# 16:28:51.317370 Found 77 light frames
# 16:28:51.317416 Observation object initialized
# 16:28:51.317458 Creating backup...
# 16:28:51.585958 Copied file to backup: 200420_Li_.00000001.23h59m03.8s_00d06m04sS.BIAS.FIT
# 16:28:51.856866 Copied file to backup: 200420_Li_.00000002.23h59m03.8s_00d06m04sS.BIAS.FIT
# 16:28:52.128577 Copied file to backup: 200420_Li_.00000003.23h59m02.8s_00d06m04sS.BIAS.FIT
# 16:28:52.404434 Copied file to backup: 200420_Li_.00000004.23h59m02.8s_00d06m04sS.BIAS.FIT
# 16:28:52.674860 Copied file to backup: 200420_Li_.00000005.23h59m02.8s_00d06m04sS.BIAS.FIT
# 16:28:52.934967 Copied file to backup: 200420_Li_.00000006.23h59m02.8s_00d06m04sS.BIAS.FIT
# 16:28:53.205301 Copied file to backup: 200420_Li_.00000007.23h59m02.8s_00d06m04sS.BIAS.FIT
# 16:28:53.470063 Copied file to backup: 200420_Li_.00000008.23h59m02.8s_00d06m04sS.BIAS.FIT
# 16:28:53.742018 Copied file to backup: 200420_Li_.00000009.23h59m02.8s_00d06m04sS.BIAS.FIT
# 16:28:54.017234 Copied file to backup: 200420_Li_.00000010.23h59m03.8s_00d06m04sS.BIAS.FIT
# 16:28:54.284975 Copied file to backup: 200420_Li_.00000011.23h59m02.8s_00d06m04sS.BIAS.FIT
# 16:28:54.553170 Copied file to backup: 200420_Li_.00000012.23h59m02.8s_00d06m04sS.DARK.FIT
# 16:28:54.823057 Copied file to backup: 200420_Li_.00000013.23h59m02.8s_00d06m04sS.DARK.FIT
# 16:28:55.089840 Copied file to backup: 200420_Li_.00000014.23h59m03.8s_00d06m04sS.DARK.FIT
# 16:28:55.353700 Copied file to backup: 200420_Li_.00000015.Mouse_click_position.FLAT.FIT
# 16:28:55.620215 Copied file to backup: 200420_Li_.00000016.08h37m29.7s_00d25m57sS.FLAT.FIT
# 16:28:55.882829 Copied file to backup: 200420_Li_.00000017.08h37m35.7s_00d26m23sS.FLAT.FIT
# 16:28:56.146374 Copied file to backup: 200420_Li_.00000018.08h37m40.7s_00d26m48sS.FLAT.FIT
# 16:28:56.409965 Copied file to backup: 200420_Li_.00000019.08h37m46.7s_00d27m14sS.FLAT.FIT
# 16:28:56.679176 Copied file to backup: 200420_Li_.00000020.08h37m46.7s_00d27m14sS.FLAT.FIT
# 16:28:56.945971 Copied file to backup: 200420_Li_.00000021.08h37m52.7s_00d27m40sS.FLAT.FIT
# 16:28:57.212210 Copied file to backup: 200420_Li_.00000022.08h37m51.7s_00d27m40sS.FLAT.FIT
# 16:28:57.480945 Copied file to backup: 200420_Li_.00000023.08h37m57.7s_00d28m06sS.FLAT.FIT
# 16:28:57.747893 Copied file to backup: 200420_Li_.00000024.08h37m55.7s_00d28m06sS.FLAT.FIT
# 16:28:58.015154 Copied file to backup: 200420_Li_.00000025.08h38m01.7s_00d28m31sS.FLAT.FIT
# 16:28:58.283165 Copied file to backup: 200420_Li_.00000026.08h38m05.7s_00d28m57sS.FLAT.FIT
# 16:28:58.540200 Copied file to backup: 200420_Li_.00000027.08h38m10.7s_00d29m23sS.FLAT.FIT
# 16:28:58.805152 Copied file to backup: 200420_Li_.00000028.08h38m15.7s_00d29m49sS.FLAT.FIT
# 16:28:59.071345 Copied file to backup: 200420_Li_.00000029.08h38m19.7s_00d30m15sS.FLAT.FIT
# 16:28:59.338778 Copied file to backup: 200420_Li_.00000030.NGC_4147.FIT
# 16:28:59.606764 Copied file to backup: 200420_Li_.00000031.NGC_4147.FIT
# 16:28:59.873332 Copied file to backup: 200420_Li_.00000032.NGC_4147.FIT
# 16:29:00.146668 Copied file to backup: 200420_Li_.00000033.NGC_4147.FIT
# 16:29:00.414930 Copied file to backup: 200420_Li_.00000034.NGC_4147.FIT
# 16:29:00.684192 Copied file to backup: 200420_Li_.00000035.NGC_4147.FIT
# 16:29:00.953820 Copied file to backup: 200420_Li_.00000036.NGC_4147.FIT
# 16:29:01.219098 Copied file to backup: 200420_Li_.00000037.NGC_4147.FIT
# 16:29:01.489983 Copied file to backup: 200420_Li_.00000038.NGC_4147.FIT
# 16:29:01.761874 Copied file to backup: 200420_Li_.00000039.NGC_4147.FIT
# 16:29:02.034688 Copied file to backup: 200420_Li_.00000040.NGC_4147.FIT
# 16:29:02.306787 Copied file to backup: 200420_Li_.00000041.NGC_4147.FIT
# 16:29:02.570474 Copied file to backup: 200420_Li_.00000042.NGC_4147.FIT
# 16:29:02.845548 Copied file to backup: 200420_Li_.00000043.NGC_4147.FIT
# 16:29:03.121063 Copied file to backup: 200420_Li_.00000044.NGC_4147.FIT
# 16:29:03.391810 Copied file to backup: 200420_Li_.00000045.NGC_4147.FIT
# 16:29:03.660630 Copied file to backup: 200420_Li_.00000046.NGC_4147.FIT
# 16:29:03.923749 Copied file to backup: 200420_Li_.00000047.NGC_4147.FIT
# 16:29:04.198223 Copied file to backup: 200420_Li_.00000048.NGC_4147.FIT
# 16:29:04.472007 Copied file to backup: 200420_Li_.00000049.NGC_4147.FIT
# 16:29:04.744453 Copied file to backup: 200420_Li_.00000050.NGC_4147.FIT
# 16:29:05.013382 Copied file to backup: 200420_Li_.00000051.NGC_4147.FIT
# 16:29:05.278890 Copied file to backup: 200420_Li_.00000052.NGC_4147.FIT
# 16:29:05.555097 Copied file to backup: 200420_Li_.00000053.Entered_Coordinates.FIT
# 16:29:05.822075 Copied file to backup: 200420_Li_.00000054.Entered_Coordinates.FIT
# 16:29:06.096090 Copied file to backup: 200420_Li_.00000055.Entered_Coordinates.FIT
# 16:29:06.363054 Copied file to backup: 200420_Li_.00000056.Entered_Coordinates.FIT
# 16:29:06.636081 Copied file to backup: 200420_Li_.00000057.Entered_Coordinates.FIT
# 16:29:06.910814 Copied file to backup: 200420_Li_.00000058.Entered_Coordinates.FIT
# 16:29:07.183075 Copied file to backup: 200420_Li_.00000059.NGC_5053.FIT
# 16:29:07.460894 Copied file to backup: 200420_Li_.00000060.NGC_5053.FIT
# 16:29:07.734709 Copied file to backup: 200420_Li_.00000061.NGC_5053.FIT
# 16:29:08.007650 Copied file to backup: 200420_Li_.00000062.NGC_5053.FIT
# 16:29:08.280288 Copied file to backup: 200420_Li_.00000063.NGC_5053.FIT
# 16:29:08.557439 Copied file to backup: 200420_Li_.00000064.NGC_5053.FIT
# 16:29:08.834092 Copied file to backup: 200420_Li_.00000065.NGC_5053.FIT
# 16:29:09.109120 Copied file to backup: 200420_Li_.00000066.NGC_5053.FIT
# 16:29:09.381145 Copied file to backup: 200420_Li_.00000067.NGC_5053.FIT
# 16:29:09.652789 Copied file to backup: 200420_Li_.00000068.NGC_5053.FIT
# 16:29:09.928938 Copied file to backup: 200420_Li_.00000069.NGC_5053.FIT
# 16:29:10.204882 Copied file to backup: 200420_Li_.00000070.NGC_5053.FIT
# 16:29:10.476875 Copied file to backup: 200420_Li_.00000071.NGC_5053.DARK.FIT
# 16:29:10.748496 Copied file to backup: 200420_Li_.00000071.NGC_5053.BIAS.FIT
# 16:29:11.018027 Copied file to backup: 200420_Li_.00000072.NGC_5053.BIAS.FIT
# 16:29:11.291723 Copied file to backup: 200420_Li_.00000073.NGC_5053.BIAS.FIT
# 16:29:11.563723 Copied file to backup: 200420_Li_.00000074.NGC_5053.BIAS.FIT
# 16:29:11.836790 Copied file to backup: 200420_Li_.00000075.NGC_5053.BIAS.FIT
# 16:29:12.104515 Copied file to backup: 200420_Li_.00000076.NGC_5053.BIAS.FIT
# 16:29:12.371194 Copied file to backup: 200420_Li_.00000077.NGC_5053.BIAS.FIT
# 16:29:12.643565 Copied file to backup: 200420_Li_.00000078.NGC_5053.BIAS.FIT
# 16:29:12.916970 Copied file to backup: 200420_Li_.00000079.NGC_5053.BIAS.FIT
# 16:29:13.188994 Copied file to backup: 200420_Li_.00000080.NGC_5053.BIAS.FIT
# 16:29:13.458418 Copied file to backup: 200420_Li_.00000081.NGC_5053.BIAS.FIT
# 16:29:13.728606 Copied file to backup: 200420_Li_.00000082.M_53.FIT
# 16:29:14.003165 Copied file to backup: 200420_Li_.00000083.M_53.FIT
# 16:29:14.276010 Copied file to backup: 200420_Li_.00000084.M_53.FIT
# 16:29:14.552622 Copied file to backup: 200420_Li_.00000085.M_53.FIT
# 16:29:14.829311 Copied file to backup: 200420_Li_.00000086.M_53.FIT
# 16:29:15.092037 Copied file to backup: 200420_Li_.00000087.M_53.FIT
# 16:29:15.362240 Copied file to backup: 200420_Li_.00000088.M_53.FIT
# 16:29:15.636470 Copied file to backup: 200420_Li_.00000089.M_53.FIT
# 16:29:15.910044 Copied file to backup: 200420_Li_.00000090.M_53.FIT
# 16:29:16.176899 Copied file to backup: 200420_Li_.00000091.M_53.FIT
# 16:29:16.440754 Copied file to backup: 200420_Li_.00000092.M_53.FIT
# 16:29:16.715100 Copied file to backup: 200420_Li_.00000093.M_53.FIT
# 16:29:16.986990 Copied file to backup: 200420_Li_.00000094.M_53.FIT
# 16:29:17.259525 Copied file to backup: 200420_Li_.00000095.M_53.FIT
# 16:29:17.534175 Copied file to backup: 200420_Li_.00000096.M_53.FIT
# 16:29:17.817877 Copied file to backup: 200420_Li_.00000097.M_53.FIT
# 16:29:18.092453 Copied file to backup: 200420_Li_.00000098.M_53.FIT
# 16:29:18.365129 Copied file to backup: 200420_Li_.00000099.M_53.FIT
# 16:29:18.640974 Copied file to backup: 200420_Li_.00000100.Entered_Coordinates.FIT
# 16:29:18.913733 Copied file to backup: 200420_Li_.00000101.Entered_Coordinates.FIT
# 16:29:19.187115 Copied file to backup: 200420_Li_.00000102.Entered_Coordinates.FIT
# 16:29:19.461385 Copied file to backup: 200420_Li_.00000104.Entered_Coordinates.FIT
# 16:29:19.731090 Copied file to backup: 200420_Li_.00000105.Entered_Coordinates.FIT
# 16:29:20.001624 Copied file to backup: 200420_Li_.00000106.Entered_Coordinates.FIT
# 16:29:20.280226 Copied file to backup: 200420_Li_.00000107.M_3.FIT
# 16:29:20.549899 Copied file to backup: 200420_Li_.00000108.M_3.FIT
# 16:29:20.817101 Copied file to backup: 200420_Li_.00000109.M_3.FIT
# 16:29:21.088022 Copied file to backup: 200420_Li_.00000110.M_3.FIT
# 16:29:21.361227 Copied file to backup: 200420_Li_.00000111.M_3.FIT
# 16:29:21.634590 Copied file to backup: 200420_Li_.00000112.M_3.FIT
# 16:29:21.909768 Copied file to backup: 200420_Li_.00000113.M_3.FIT
# 16:29:22.180947 Copied file to backup: 200420_Li_.00000114.M_3.FIT
# 16:29:22.449998 Copied file to backup: 200420_Li_.00000115.M_3.FIT
# 16:29:22.712973 Copied file to backup: 200420_Li_.00000116.M_3.FIT
# 16:29:22.981522 Copied file to backup: 200420_Li_.00000117.M_3.FIT
# 16:29:23.246553 Copied file to backup: 200420_Li_.00000118.M_3.FIT
# 16:29:23.511354 Copied file to backup: 200420_Li_.00000119.M_3.BIAS.FIT
# 16:29:23.797201 Copied file to backup: 200420_Li_.00000120.M_3.BIAS.FIT
# 16:29:24.074885 Copied file to backup: 200420_Li_.00000121.M_3.BIAS.FIT
# 16:29:24.343245 Copied file to backup: 200420_Li_.00000122.M_3.BIAS.FIT
# 16:29:24.617022 Copied file to backup: 200420_Li_.00000123.M_3.BIAS.FIT
# 16:29:24.626472 Backup created!
# 16:29:24.626554 Saving correction frames...
# 16:29:28.201723 /net/dataserver3/data/users/noelstorr/blaauwpipe/200420/STL-6303E/i/Correction/master_bias1x1C1.fits created
# 16:29:31.223891 /net/dataserver3/data/users/noelstorr/blaauwpipe/200420/STL-6303E/i/Correction/master_bias1x1C2.fits created
# 16:29:32.694400 /net/dataserver3/data/users/noelstorr/blaauwpipe/200420/STL-6303E/i/Correction/master_bias1x1C3.fits created
# 16:29:34.509061 /net/dataserver3/data/users/noelstorr/blaauwpipe/200420/STL-6303E/i/Correction/master_dark1x1C1.fits created
# 16:29:35.147020 /net/dataserver3/data/users/noelstorr/blaauwpipe/200420/STL-6303E/i/Correction/master_dark1x1C2.fits created
# 16:29:38.869667 /net/dataserver3/data/users/noelstorr/blaauwpipe/200420/STL-6303E/i/Correction/master_flat1x1BC1.fits created
# 16:29:41.985296 /net/dataserver3/data/users/noelstorr/blaauwpipe/200420/STL-6303E/i/Correction/master_flat1x1VC1.fits created
# 16:29:45.543311 /net/dataserver3/data/users/noelstorr/blaauwpipe/200420/STL-6303E/i/Correction/master_flat1x1RC1.fits created
# 16:29:45.553785 Correction frames saved!
# 16:29:45.553883 Reducing images...
# 16:29:46.381342 /net/dataserver3/data/users/noelstorr/blaauwpipe/200420/STL-6303E/i/Reduced/200420_Li_.00000030.NGC_4147.FIT created
# 16:29:47.196290 /net/dataserver3/data/users/noelstorr/blaauwpipe/200420/STL-6303E/i/Reduced/200420_Li_.00000031.NGC_4147.FIT created
# 16:29:47.949985 /net/dataserver3/data/users/noelstorr/blaauwpipe/200420/STL-6303E/i/Reduced/200420_Li_.00000032.NGC_4147.FIT created
# 16:29:48.667036 /net/dataserver3/data/users/noelstorr/blaauwpipe/200420/STL-6303E/i/Reduced/200420_Li_.00000033.NGC_4147.FIT created
# 16:29:49.382546 /net/dataserver3/data/users/noelstorr/blaauwpipe/200420/STL-6303E/i/Reduced/200420_Li_.00000034.NGC_4147.FIT created
# 16:29:50.105727 /net/dataserver3/data/users/noelstorr/blaauwpipe/200420/STL-6303E/i/Reduced/200420_Li_.00000035.NGC_4147.FIT created
# 16:29:50.824626 /net/dataserver3/data/users/noelstorr/blaauwpipe/200420/STL-6303E/i/Reduced/200420_Li_.00000036.NGC_4147.FIT created
# 16:29:51.529160 /net/dataserver3/data/users/noelstorr/blaauwpipe/200420/STL-6303E/i/Reduced/200420_Li_.00000037.NGC_4147.FIT created
# 16:29:52.264091 /net/dataserver3/data/users/noelstorr/blaauwpipe/200420/STL-6303E/i/Reduced/200420_Li_.00000038.NGC_4147.FIT created
# 16:29:53.001451 /net/dataserver3/data/users/noelstorr/blaauwpipe/200420/STL-6303E/i/Reduced/200420_Li_.00000039.NGC_4147.FIT created
# 16:29:53.712602 /net/dataserver3/data/users/noelstorr/blaauwpipe/200420/STL-6303E/i/Reduced/200420_Li_.00000040.NGC_4147.FIT created
# 16:29:54.452187 /net/dataserver3/data/users/noelstorr/blaauwpipe/200420/STL-6303E/i/Reduced/200420_Li_.00000041.NGC_4147.FIT created
# 16:29:55.200952 /net/dataserver3/data/users/noelstorr/blaauwpipe/200420/STL-6303E/i/Reduced/200420_Li_.00000042.NGC_4147.FIT created
# 16:29:55.961746 /net/dataserver3/data/users/noelstorr/blaauwpipe/200420/STL-6303E/i/Reduced/200420_Li_.00000043.NGC_4147.FIT created
# 16:29:56.705890 /net/dataserver3/data/users/noelstorr/blaauwpipe/200420/STL-6303E/i/Reduced/200420_Li_.00000044.NGC_4147.FIT created
# 16:29:57.445388 /net/dataserver3/data/users/noelstorr/blaauwpipe/200420/STL-6303E/i/Reduced/200420_Li_.00000045.NGC_4147.FIT created
# 16:29:58.218369 /net/dataserver3/data/users/noelstorr/blaauwpipe/200420/STL-6303E/i/Reduced/200420_Li_.00000046.NGC_4147.FIT created
# 16:29:58.943414 /net/dataserver3/data/users/noelstorr/blaauwpipe/200420/STL-6303E/i/Reduced/200420_Li_.00000047.NGC_4147.FIT created
# 16:29:59.686926 /net/dataserver3/data/users/noelstorr/blaauwpipe/200420/STL-6303E/i/Reduced/200420_Li_.00000048.NGC_4147.FIT created
# 16:30:00.431748 /net/dataserver3/data/users/noelstorr/blaauwpipe/200420/STL-6303E/i/Reduced/200420_Li_.00000049.NGC_4147.FIT created
# 16:30:01.141476 /net/dataserver3/data/users/noelstorr/blaauwpipe/200420/STL-6303E/i/Reduced/200420_Li_.00000050.NGC_4147.FIT created
# 16:30:01.875650 /net/dataserver3/data/users/noelstorr/blaauwpipe/200420/STL-6303E/i/Reduced/200420_Li_.00000051.NGC_4147.FIT created
# 16:30:02.607756 /net/dataserver3/data/users/noelstorr/blaauwpipe/200420/STL-6303E/i/Reduced/200420_Li_.00000052.NGC_4147.FIT created
# 16:30:03.352148 /net/dataserver3/data/users/noelstorr/blaauwpipe/200420/STL-6303E/i/Reduced/200420_Li_.00000053.Entered_Coordinates.FIT created
# 16:30:04.076151 /net/dataserver3/data/users/noelstorr/blaauwpipe/200420/STL-6303E/i/Reduced/200420_Li_.00000054.Entered_Coordinates.FIT created
# 16:30:04.811509 /net/dataserver3/data/users/noelstorr/blaauwpipe/200420/STL-6303E/i/Reduced/200420_Li_.00000055.Entered_Coordinates.FIT created
# 16:30:05.541237 /net/dataserver3/data/users/noelstorr/blaauwpipe/200420/STL-6303E/i/Reduced/200420_Li_.00000056.Entered_Coordinates.FIT created
# 16:30:06.268145 /net/dataserver3/data/users/noelstorr/blaauwpipe/200420/STL-6303E/i/Reduced/200420_Li_.00000057.Entered_Coordinates.FIT created
# 16:30:07.005813 /net/dataserver3/data/users/noelstorr/blaauwpipe/200420/STL-6303E/i/Reduced/200420_Li_.00000058.Entered_Coordinates.FIT created
# 16:30:07.760157 /net/dataserver3/data/users/noelstorr/blaauwpipe/200420/STL-6303E/i/Reduced/200420_Li_.00000059.NGC_5053.FIT created
# 16:30:08.506774 /net/dataserver3/data/users/noelstorr/blaauwpipe/200420/STL-6303E/i/Reduced/200420_Li_.00000060.NGC_5053.FIT created
# 16:30:09.236913 /net/dataserver3/data/users/noelstorr/blaauwpipe/200420/STL-6303E/i/Reduced/200420_Li_.00000061.NGC_5053.FIT created
# 16:30:09.981493 /net/dataserver3/data/users/noelstorr/blaauwpipe/200420/STL-6303E/i/Reduced/200420_Li_.00000062.NGC_5053.FIT created
# 16:30:10.720679 /net/dataserver3/data/users/noelstorr/blaauwpipe/200420/STL-6303E/i/Reduced/200420_Li_.00000063.NGC_5053.FIT created
# 16:30:11.501437 /net/dataserver3/data/users/noelstorr/blaauwpipe/200420/STL-6303E/i/Reduced/200420_Li_.00000064.NGC_5053.FIT created
# 16:30:12.247756 /net/dataserver3/data/users/noelstorr/blaauwpipe/200420/STL-6303E/i/Reduced/200420_Li_.00000065.NGC_5053.FIT created
# 16:30:12.982115 /net/dataserver3/data/users/noelstorr/blaauwpipe/200420/STL-6303E/i/Reduced/200420_Li_.00000066.NGC_5053.FIT created
# 16:30:13.759209 /net/dataserver3/data/users/noelstorr/blaauwpipe/200420/STL-6303E/i/Reduced/200420_Li_.00000067.NGC_5053.FIT created
# 16:30:14.535876 /net/dataserver3/data/users/noelstorr/blaauwpipe/200420/STL-6303E/i/Reduced/200420_Li_.00000068.NGC_5053.FIT created
# 16:30:15.272828 /net/dataserver3/data/users/noelstorr/blaauwpipe/200420/STL-6303E/i/Reduced/200420_Li_.00000069.NGC_5053.FIT created
# 16:30:16.025229 /net/dataserver3/data/users/noelstorr/blaauwpipe/200420/STL-6303E/i/Reduced/200420_Li_.00000070.NGC_5053.FIT created
# 16:30:17.146176 /net/dataserver3/data/users/noelstorr/blaauwpipe/200420/STL-6303E/i/Reduced/200420_Li_.00000082.M_53.FIT created
# 16:30:17.902522 /net/dataserver3/data/users/noelstorr/blaauwpipe/200420/STL-6303E/i/Reduced/200420_Li_.00000083.M_53.FIT created
# 16:30:18.641773 /net/dataserver3/data/users/noelstorr/blaauwpipe/200420/STL-6303E/i/Reduced/200420_Li_.00000084.M_53.FIT created
# 16:30:19.399451 /net/dataserver3/data/users/noelstorr/blaauwpipe/200420/STL-6303E/i/Reduced/200420_Li_.00000085.M_53.FIT created
# 16:30:20.144426 /net/dataserver3/data/users/noelstorr/blaauwpipe/200420/STL-6303E/i/Reduced/200420_Li_.00000086.M_53.FIT created
# 16:30:20.875704 /net/dataserver3/data/users/noelstorr/blaauwpipe/200420/STL-6303E/i/Reduced/200420_Li_.00000087.M_53.FIT created
# 16:30:21.633911 /net/dataserver3/data/users/noelstorr/blaauwpipe/200420/STL-6303E/i/Reduced/200420_Li_.00000088.M_53.FIT created
# 16:30:22.385191 /net/dataserver3/data/users/noelstorr/blaauwpipe/200420/STL-6303E/i/Reduced/200420_Li_.00000089.M_53.FIT created
# 16:30:23.132166 /net/dataserver3/data/users/noelstorr/blaauwpipe/200420/STL-6303E/i/Reduced/200420_Li_.00000090.M_53.FIT created
# 16:30:23.877103 /net/dataserver3/data/users/noelstorr/blaauwpipe/200420/STL-6303E/i/Reduced/200420_Li_.00000091.M_53.FIT created
# 16:30:24.635726 /net/dataserver3/data/users/noelstorr/blaauwpipe/200420/STL-6303E/i/Reduced/200420_Li_.00000092.M_53.FIT created
# 16:30:25.375275 /net/dataserver3/data/users/noelstorr/blaauwpipe/200420/STL-6303E/i/Reduced/200420_Li_.00000093.M_53.FIT created
# 16:30:26.107399 /net/dataserver3/data/users/noelstorr/blaauwpipe/200420/STL-6303E/i/Reduced/200420_Li_.00000094.M_53.FIT created
# 16:30:26.815685 /net/dataserver3/data/users/noelstorr/blaauwpipe/200420/STL-6303E/i/Reduced/200420_Li_.00000095.M_53.FIT created
# 16:30:27.545919 /net/dataserver3/data/users/noelstorr/blaauwpipe/200420/STL-6303E/i/Reduced/200420_Li_.00000096.M_53.FIT created
# 16:30:28.293422 /net/dataserver3/data/users/noelstorr/blaauwpipe/200420/STL-6303E/i/Reduced/200420_Li_.00000097.M_53.FIT created
# 16:30:29.039144 /net/dataserver3/data/users/noelstorr/blaauwpipe/200420/STL-6303E/i/Reduced/200420_Li_.00000098.M_53.FIT created
# 16:30:29.770524 /net/dataserver3/data/users/noelstorr/blaauwpipe/200420/STL-6303E/i/Reduced/200420_Li_.00000099.M_53.FIT created
# 16:30:30.503004 /net/dataserver3/data/users/noelstorr/blaauwpipe/200420/STL-6303E/i/Reduced/200420_Li_.00000100.Entered_Coordinates.FIT created
# 16:30:31.247521 /net/dataserver3/data/users/noelstorr/blaauwpipe/200420/STL-6303E/i/Reduced/200420_Li_.00000101.Entered_Coordinates.FIT created
# 16:30:31.963067 /net/dataserver3/data/users/noelstorr/blaauwpipe/200420/STL-6303E/i/Reduced/200420_Li_.00000102.Entered_Coordinates.FIT created
# 16:30:32.690757 /net/dataserver3/data/users/noelstorr/blaauwpipe/200420/STL-6303E/i/Reduced/200420_Li_.00000104.Entered_Coordinates.FIT created
# 16:30:33.417888 /net/dataserver3/data/users/noelstorr/blaauwpipe/200420/STL-6303E/i/Reduced/200420_Li_.00000105.Entered_Coordinates.FIT created
# 16:30:34.172948 /net/dataserver3/data/users/noelstorr/blaauwpipe/200420/STL-6303E/i/Reduced/200420_Li_.00000106.Entered_Coordinates.FIT created
# 16:30:34.925529 /net/dataserver3/data/users/noelstorr/blaauwpipe/200420/STL-6303E/i/Reduced/200420_Li_.00000107.M_3.FIT created
# 16:30:35.656971 /net/dataserver3/data/users/noelstorr/blaauwpipe/200420/STL-6303E/i/Reduced/200420_Li_.00000108.M_3.FIT created
# 16:30:36.401390 /net/dataserver3/data/users/noelstorr/blaauwpipe/200420/STL-6303E/i/Reduced/200420_Li_.00000109.M_3.FIT created
# 16:30:37.164744 /net/dataserver3/data/users/noelstorr/blaauwpipe/200420/STL-6303E/i/Reduced/200420_Li_.00000110.M_3.FIT created
# 16:30:37.922362 /net/dataserver3/data/users/noelstorr/blaauwpipe/200420/STL-6303E/i/Reduced/200420_Li_.00000111.M_3.FIT created
# 16:30:38.707612 /net/dataserver3/data/users/noelstorr/blaauwpipe/200420/STL-6303E/i/Reduced/200420_Li_.00000112.M_3.FIT created
# 16:30:39.449195 /net/dataserver3/data/users/noelstorr/blaauwpipe/200420/STL-6303E/i/Reduced/200420_Li_.00000113.M_3.FIT created
# 16:30:40.206336 /net/dataserver3/data/users/noelstorr/blaauwpipe/200420/STL-6303E/i/Reduced/200420_Li_.00000114.M_3.FIT created
# 16:30:40.951923 /net/dataserver3/data/users/noelstorr/blaauwpipe/200420/STL-6303E/i/Reduced/200420_Li_.00000115.M_3.FIT created
# 16:30:41.716232 /net/dataserver3/data/users/noelstorr/blaauwpipe/200420/STL-6303E/i/Reduced/200420_Li_.00000116.M_3.FIT created
# 16:30:42.453415 /net/dataserver3/data/users/noelstorr/blaauwpipe/200420/STL-6303E/i/Reduced/200420_Li_.00000117.M_3.FIT created
# 16:30:43.176222 /net/dataserver3/data/users/noelstorr/blaauwpipe/200420/STL-6303E/i/Reduced/200420_Li_.00000118.M_3.FIT created
# 16:30:43.232299 Images reduced!

# %%
import configparser

config = configparser.ConfigParser()
config['CORE'] = {}

enabled_plugins = {}
for plugin in loaded_plugins:
    enabled_plugins[type(plugin).__name__] = True
    
config['ENABLED PLUGINS'] = {type(plugin).__name__}

with open('config.ini', 'w') as configfile:
    config.write(configfile)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-05a1e29c8cbe> in <module>
#       5
#       6 enabled_plugins = {}
# ----> 7 for plugin in loaded_plugins:
#       8     enabled_plugins[type(plugin).__name__] = True
#       9
#
# NameError: name 'loaded_plugins' is not defined
